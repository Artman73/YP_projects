# %% [markdown]
# <h1> Комментарий тимлида </h1>
#
# Привет, Роман, рада с тобой познакомиться!
# Меня зовут Виктория Ильина, и я буду проверять твою работу.
#
#  Я буду использовать различные цвета, чтобы было легче воспринимать мои комментарии:
#
# <div class="alert alert-block alert-danger">
# <b>Комментарий тимлида❌:</b> Так выделены самые важные замечания. Без их отработки план не будет принят.
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Комментарий тимлида🤔:</b> Так выделены небольшие замечания. Одно-два таких замечания допустимы, но если их будет больше - тебе будет необходимо внести исправления.
# </div>
#
# <div class="alert alert-block alert-success">
# <b>Комментарий тимлида👍:</b> Так я выделю все остальные комментарии.
# </div>
#
# Давай посмотрим, что получилось!

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента👍:</b> Виктория привет! давай посмотрим)
# </div>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#План" data-toc-modified-id="План-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>План</a></span></li><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#EDA-(Exploratory-Data-Analysis-/-Исследовательский-анализ-данных)" data-toc-modified-id="EDA-(Exploratory-Data-Analysis-/-Исследовательский-анализ-данных)-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>EDA (Exploratory Data Analysis / Исследовательский анализ данных)</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Вопросы-по-плану-и-EDA" data-toc-modified-id="Вопросы-по-плану-и-EDA-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Вопросы по плану и EDA</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Работа-с-пропусками" data-toc-modified-id="Работа-с-пропусками-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Работа с пропусками</a></span></li><li><span><a href="#Применим-технику-прямого-кодирования-One-Hot-Encoding-(OHE)" data-toc-modified-id="Применим-технику-прямого-кодирования-One-Hot-Encoding-(OHE)-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Применим технику прямого кодирования One-Hot Encoding (OHE)</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Обучение-и-CV.-Выобор-AUC-ROC-лучшей-модели" data-toc-modified-id="Обучение-и-CV.-Выобор-AUC-ROC-лучшей-модели-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Обучение и CV. Выобор AUC-ROC лучшей модели</a></span><ul class="toc-item"><li><span><a href="#Проверка-адекватности-модели.-Константная-модель" data-toc-modified-id="Проверка-адекватности-модели.-Константная-модель-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Проверка адекватности модели. Константная модель</a></span></li><li><span><a href="#LogisticRegression-+-class_weight='balanced'" data-toc-modified-id="LogisticRegression-+-class_weight='balanced'-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>LogisticRegression + class_weight='balanced'</a></span></li><li><span><a href="#RandomForestClassifier-+-class_weight='balanced'-+-GridSearchCV" data-toc-modified-id="RandomForestClassifier-+-class_weight='balanced'-+-GridSearchCV-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>RandomForestClassifier + class_weight='balanced' + GridSearchCV</a></span></li><li><span><a href="#CatBoostClassifier-+-GridSearchCV" data-toc-modified-id="CatBoostClassifier-+-GridSearchCV-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>CatBoostClassifier + GridSearchCV</a></span></li><li><span><a href="#CatBoostClassifier-+-GridSearchCV-+-upsampling" data-toc-modified-id="CatBoostClassifier-+-GridSearchCV-+-upsampling-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>CatBoostClassifier + GridSearchCV + upsampling</a></span><ul class="toc-item"><li><span><a href="#Техника-увеличения-качества-модели-при-дисбалансе-классов:-upsampling" data-toc-modified-id="Техника-увеличения-качества-модели-при-дисбалансе-классов:-upsampling-7.5.1"><span class="toc-item-num">7.5.1&nbsp;&nbsp;</span>Техника увеличения качества модели при дисбалансе классов: upsampling</a></span></li></ul></li><li><span><a href="#Вывод,-результаты-обучения" data-toc-modified-id="Вывод,-результаты-обучения-7.6"><span class="toc-item-num">7.6&nbsp;&nbsp;</span>Вывод, результаты обучения</a></span></li></ul></li><li><span><a href="#Тестирование-лучшей-модели-CatBoostClassifier-+-GridSearchCV" data-toc-modified-id="Тестирование-лучшей-модели-CatBoostClassifier-+-GridSearchCV-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Тестирование лучшей модели CatBoostClassifier + GridSearchCV</a></span><ul class="toc-item"><li><span><a href="#Построим-график-важности-признаков-для-итоговой-модели" data-toc-modified-id="Построим-график-важности-признаков-для-итоговой-модели-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Построим график важности признаков для итоговой модели</a></span></li><li><span><a href="#график:-ROC-кривая" data-toc-modified-id="график:-ROC-кривая-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>график: ROC-кривая</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Эксперимент.-Проверим-метрики,-обучив-модель-только-на-наиболее-важных-признаках-по-графику,-поменяем-столбцы-и-изучим-метрики" data-toc-modified-id="Эксперимент.-Проверим-метрики,-обучив-модель-только-на-наиболее-важных-признаках-по-графику,-поменяем-столбцы-и-изучим-метрики-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Эксперимент. Проверим метрики, обучив модель только на наиболее важных признаках по графику, поменяем столбцы и изучим метрики</a></span></li><li><span><a href="#Отчет" data-toc-modified-id="Отчет-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Отчет</a></span></li></ul></div>

# %% [markdown]
# # Название проекта: Прогнозирование оттока клиентов

# %% [markdown]
# ## Описание проекта
# - Оператор связи «Ниединогоразрыва.ком» хочет научиться прогнозировать отток клиентов. Если выяснится, что пользователь планирует уйти, ему будут предложены промокоды и специальные условия. Команда оператора собрала персональные данные о некоторых клиентах, информацию об их тарифах и договорах.
# - Информация о договорах актуальна на 1 февраля 2020.

# %% [markdown]
# ## План
# - 1 Применим технику прямого кодирования One-Hot Encoding (OHE)
# (Чтобы не попасть в dummy trap , применим аргумент drop_first функции pd.get_dummies())
# Наши данные содержат категориальные признаки.
# Принадлежность к категории к примеру логистическая регрессия вычисляет по формуле, состоящей из признаков.
# Они могут быть только численные.
# Поэтому применим технику прямого кодирования One-Hot Encoding, OHE.
# Она подходит для решения нашей задачи: работает со всеми моделями.
# - 2 Разделим исходные данные на обучающую и тестовую выборки.
# - 3 Применим масштабирование признаков методом стандартизации данных
# - 4 Исследуем баланс классов. для подсчёта классов в целевом признаке применим метод value_counts()
# И создадим константную модель, проверим ее метрики
# - 5 Обучим модели, проверим метрики F1-мера + AUC-ROC
# LogisticRegression
# DecisionTreeClassifier
# RandomForestClassifier
# LGBMClassifier
# CatBoostClassifier
# Используем GridSearchCV/RandomizedSearchCV
# - 6 Улучшим качество модели, учитывая дисбаланс классов. Обучим разные модели и найдем лучшую.
# --Техника увеличения качества модели при дисбалансе классов: Взвешивание классов (class_weight='balanced')
# --Техника увеличения качества модели при дисбалансе классов: upsampling
# - 7 При необходимости (если низкие метрики) создать дополнительные признаки или запустим на длительный период (несколько часов) для подбора лучших гиперпараметров
# - 8 Отчет

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий тимлида👍:</b> Согласна =)
# </div>

# %% [markdown]
# ## Загрузка данных

# %%
#pip install phik

# %%
#Импорт библиотек
import pandas as pd
import numpy as np
from scipy import stats as st

#хитмэп корреляции
import os
import seaborn as sns #построение графиков

import matplotlib.pyplot as plt

#операции с выборкой
from sklearn.model_selection import train_test_split

#сохранение модели
import joblib 
from joblib import dump

#классификация
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression 
from catboost import CatBoostClassifier

#преобразователь масштаба методом стандартизации
from sklearn.preprocessing import StandardScaler

#метрики
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score #кросс-валидация
from sklearn.metrics import make_scorer #для написания ручной оценки

#подбор параметров
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV

#построение ROC-кривой
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import roc_curve 
from sklearn.metrics import roc_auc_score

#раздел upsampling
from sklearn.utils import shuffle

#библиотека CatBoost
import catboost as cb
from catboost import CatBoostRegressor

#для графиков
import pylab
#plt.style.use('ggplot')

#Phi_K Correlation Analyzer Library
import phik
from phik import resources, report
from phik.report import plot_correlation_matrix

from datetime import datetime

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий тимлида🤔:</b> Пожалуйста, удали все неиспользуемые инструменты
# </div>

# %%
# Сброс ограничений на число столбцов
pd.set_option('display.max_columns', None)

# Сброс ограничений на количество выводимых строк
#pd.set_option('display.max_rows', None)
  
# Сброс ограничений на количество символов в записи
#pd.set_option('display.max_colwidth', None)

# %%
#загрузим датасет
try:
    contract = pd.read_csv('contract.csv')
    personal = pd.read_csv('personal.csv')
    internet = pd.read_csv('internet.csv')
    phone = pd.read_csv('phone.csv')
    
except FileNotFoundError:
    contract = pd.read_csv('/datasets/final_provider/contract.csv')
    personal = pd.read_csv('/datasets/final_provider/personal.csv')
    internet = pd.read_csv('/datasets/final_provider/internet.csv')
    phone = pd.read_csv('/datasets/final_provider/phone.csv')

# %% [markdown]
# ## EDA (Exploratory Data Analysis / Исследовательский анализ данных)

# %%
#проверим информацию по датасетам
def get_df_name(df):
    name =[x for x in globals() if globals()[x] is df][0]
    return name

for df in [contract, personal, internet, phone]:
    print('\n', '***', get_df_name(df), '\n')
    display(df, df.info(), df.describe())
# Out:
#  *** contract
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   BeginDate         7043 non-null   object
#  2   EndDate           7043 non-null   object
#  3   Type              7043 non-null   object
#  4   PaperlessBilling  7043 non-null   object
#  5   PaymentMethod     7043 non-null   object
#  6   MonthlyCharges    7043 non-null   float64
#  7   TotalCharges      7043 non-null   object
# dtypes: float64(1), object(7)
# memory usage: 440.3+ KB
#       customerID   BeginDate              EndDate            Type  \
# 0     7590-VHVEG  2020-01-01                   No  Month-to-month
# 1     5575-GNVDE  2017-04-01                   No        One year
# 2     3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month
# ...

# %%
contract.isnull().sum()
# Out:
# customerID          0
# BeginDate           0
# EndDate             0
# Type                0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# dtype: int64

# %%
#объединим датасеты
merge_1 = contract.merge(personal, on='customerID', how='outer', suffixes=('', '')) 
merge_2 = merge_1.merge(internet, on='customerID', how='outer', suffixes=('', '')) 
merge_3 = merge_2.merge(phone, on='customerID', how='outer', suffixes=('', '')) 
full_df = merge_3
full_df
# Out:
#       customerID   BeginDate              EndDate            Type  \
# 0     7590-VHVEG  2020-01-01                   No  Month-to-month
# 1     5575-GNVDE  2017-04-01                   No        One year
# 2     3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month
# 3     7795-CFOCW  2016-05-01                   No        One year
# 4     9237-HQITU  2019-09-01  2019-11-01 00:00:00  Month-to-month
# ...          ...         ...                  ...             ...
# 7038  6840-RESVB  2018-02-01                   No        One year
# 7039  2234-XADUH  2014-02-01                   No        One year
# 7040  4801-JZAZL  2019-03-01                   No  Month-to-month
# 7041  8361-LTMKD  2019-07-01  2019-11-01 00:00:00  Month-to-month
# 7042  3186-AJIEK  2014-08-01                   No        Two year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges  \
# 0                 Yes           Electronic check           29.85        29.85
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий тимлида👍:</b> При объединении никто не потерялся =)
# </div>

# %%
#проверим пропуски после объединения
full_df.isnull().sum()
# Out:
# customerID             0
# BeginDate              0
# EndDate                0
# Type                   0
# PaperlessBilling       0
# PaymentMethod          0
# MonthlyCharges         0
# TotalCharges           0
# gender                 0
# SeniorCitizen          0
# Partner                0
# Dependents             0
# InternetService     1526
# OnlineSecurity      1526
# OnlineBackup        1526
# DeviceProtection    1526
# TechSupport         1526
# StreamingTV         1526
# StreamingMovies     1526
# MultipleLines        682
# dtype: int64

# %%
#преобразуем типы данных, добавим целевой признак, время использования сервиса(дни и месяцы), удалим неинформ столбцы
full_df['TotalCharges'] = pd.to_numeric(full_df['TotalCharges'], errors='coerce')

full_df['target'] = full_df['EndDate']
full_df.loc[full_df['EndDate'] != 'No', 'target'] = 1
full_df.loc[full_df['EndDate'] == 'No', 'target'] = 0

full_df['BeginDate'] = pd.to_datetime(full_df['BeginDate'], format='%Y-%m-%d')
full_df['EndDate'] = pd.to_datetime(full_df['EndDate'], errors='coerce', format='%Y-%m-%d %H:%M:%S')

full_df['duration_service_d'] = (full_df['EndDate'] - full_df['BeginDate']).dt.days
full_df['duration_service_m'] = round((full_df['EndDate'] - full_df['BeginDate']).dt.days/30)

full_df['duration_service_d'] = full_df['duration_service_d'].fillna(
    (datetime.strptime("2020-02-01", "%Y-%m-%d") - full_df['BeginDate']).dt.days)
full_df['duration_service_m'] = full_df['duration_service_m'].fillna(
    round((datetime.strptime("2020-02-01", "%Y-%m-%d") - full_df['BeginDate']).dt.days/30))

full_df = full_df.drop(columns=['customerID'], axis=1)

full_df['target'] = pd.to_numeric(full_df['target'], errors='coerce')

full_df.info()
full_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   BeginDate           7043 non-null   datetime64[ns]
#  1   EndDate             1869 non-null   datetime64[ns]
#  2   Type                7043 non-null   object
#  3   PaperlessBilling    7043 non-null   object
#  4   PaymentMethod       7043 non-null   object
#  5   MonthlyCharges      7043 non-null   float64
#  6   TotalCharges        7032 non-null   float64
#  7   gender              7043 non-null   object
#  8   SeniorCitizen       7043 non-null   int64
#  9   Partner             7043 non-null   object
#  10  Dependents          7043 non-null   object
#  11  InternetService     5517 non-null   object
#  12  OnlineSecurity      5517 non-null   object
#  13  OnlineBackup        5517 non-null   object
#  14  DeviceProtection    5517 non-null   object
# ...

# %%
#проверим пропуски после изменения данных
full_df.isnull().sum()
# Out:
# BeginDate                0
# EndDate               5174
# Type                     0
# PaperlessBilling         0
# PaymentMethod            0
# MonthlyCharges           0
# TotalCharges            11
# gender                   0
# SeniorCitizen            0
# Partner                  0
# Dependents               0
# InternetService       1526
# OnlineSecurity        1526
# OnlineBackup          1526
# DeviceProtection      1526
# TechSupport           1526
# StreamingTV           1526
# StreamingMovies       1526
# MultipleLines          682
# target                   0
# duration_service_d       0
# duration_service_m       0
# dtype: int64

# %%
#проверим строки с пропусками TotalCharges на предмет удаления/заполнения
full_df.loc[full_df['TotalCharges'].isnull()]
# Out:
#       BeginDate EndDate      Type PaperlessBilling              PaymentMethod  \
# 488  2020-02-01     NaT  Two year              Yes  Bank transfer (automatic)
# 753  2020-02-01     NaT  Two year               No               Mailed check
# 936  2020-02-01     NaT  Two year               No               Mailed check
# 1082 2020-02-01     NaT  Two year               No               Mailed check
# 1340 2020-02-01     NaT  Two year               No    Credit card (automatic)
# 3331 2020-02-01     NaT  Two year               No               Mailed check
# 3826 2020-02-01     NaT  Two year               No               Mailed check
# 4380 2020-02-01     NaT  Two year               No               Mailed check
# 5218 2020-02-01     NaT  One year              Yes               Mailed check
# 6670 2020-02-01     NaT  Two year               No               Mailed check
# 6754 2020-02-01     NaT  Two year              Yes  Bank transfer (automatic)
#
# ...

# %%
#пропуски решено заполнить, вероятно оплаты еще просто не поступало согласно дате BeginDate начала договора обслуживания
full_df['TotalCharges'] = full_df['TotalCharges'].fillna(0)
full_df.isnull().sum()
# Out:
# BeginDate                0
# EndDate               5174
# Type                     0
# PaperlessBilling         0
# PaymentMethod            0
# MonthlyCharges           0
# TotalCharges             0
# gender                   0
# SeniorCitizen            0
# Partner                  0
# Dependents               0
# InternetService       1526
# OnlineSecurity        1526
# OnlineBackup          1526
# DeviceProtection      1526
# TechSupport           1526
# StreamingTV           1526
# StreamingMovies       1526
# MultipleLines          682
# target                   0
# duration_service_d       0
# duration_service_m       0
# dtype: int64

# %%
#1 построим phik матрицу корреляции
interval_cols =  ['MonthlyCharges', 'TotalCharges']
phik_overview = full_df.phik_matrix(interval_cols=interval_cols)

plot_correlation_matrix(phik_overview.values, 
                        x_labels=phik_overview.columns, 
                        y_labels=phik_overview.index, 
                        vmin=0, vmax=1, color_map="Greens", 
                        title=r"correlation $\phi_K$", 
                        fontsize_factor=1.5, 
                        figsize=(16, 12))
plt.tight_layout()

# %%
#2 построим phik матрицу корреляции

full_df = full_df.drop(columns=['gender', 'BeginDate', 'EndDate'], axis=1)

interval_cols =  ['MonthlyCharges', 'TotalCharges']
phik_overview = full_df.phik_matrix(interval_cols=interval_cols)

plot_correlation_matrix(phik_overview.values, 
                        x_labels=phik_overview.columns, 
                        y_labels=phik_overview.index, 
                        vmin=0, vmax=1, color_map="Greens", 
                        title=r"correlation $\phi_K$", 
                        fontsize_factor=1.5, 
                        figsize=(16, 12))
plt.tight_layout()

# %%
#3 построим phik матрицу корреляции

full_df = full_df.drop(columns=['duration_service_m', 'MonthlyCharges'], axis=1)

interval_cols =  ['MonthlyCharges', 'TotalCharges']
phik_overview = full_df.phik_matrix(interval_cols=interval_cols)

plot_correlation_matrix(phik_overview.values, 
                        x_labels=phik_overview.columns, 
                        y_labels=phik_overview.index, 
                        vmin=0, vmax=1, color_map="Greens", 
                        title=r"correlation $\phi_K$", 
                        fontsize_factor=1.5, 
                        figsize=(16, 12))
plt.tight_layout()

# %%
#график распределения времени работы для тех кто расторг договор
contract_off = full_df.query('target == 1')

#построим график распределения
contract_off.plot(y='duration_service_d', kind='hist', bins=200, figsize=(15, 7))
plt.title('График распределения количества клиентов от времени работы (договор закрыт)', fontsize=20, fontweight='bold')
plt.xlabel('Количество клиентов', fontsize=16)
plt.ylabel('Время работы, дней', fontsize=16)
# Out:
# Text(0, 0.5, 'Время работы, дней')

# %%
#график распределения времени работы для тех кто обслуживается
contract_on = full_df.query('target == 0')

#построим график распределения
contract_on.plot(y='duration_service_d', kind='hist', bins=200, figsize=(15, 7))
plt.title('График распределения количества клиентов от времени работы (на обслуживании)', fontsize=20, fontweight='bold')
plt.xlabel('Количество клиентов', fontsize=16)
plt.ylabel('Время работы, дней', fontsize=16)
# Out:
# Text(0, 0.5, 'Время работы, дней')

# %% [markdown]
# ### Вывод
# - при анализе данных выявлены замечания по оформлению названий столбцов (snake_case) и типизации данных дат и итоговой оплаты, типы исправлены
# - после сведения таблиц в общую - появились пропуски, пропуски заполним 'No', тк услуги не оказывались
# - отсутствует целевой признак, добавлен, опираясь на то что "Информация о договорах актуальна на 1 февраля 2020"
# - добавлены признаки дней и месяцев обслуживания клиентов
# - при построении первой phik матрицы корреляции выявлен столбец не влияющий на таргет- gender, решено удалить, также удаляем столбцы с датами
# - также  удалим признак срока в месяцах -duration_service_m тк коррелирует с duration_service_d, у duration_service_m - с таргетом связь меньше
# - аналогично удалим признак MonthlyCharges тк коррелирует с InternetService, но - с таргетом связь меньше
# - наблюдаем дисбаланс классов, который отразится на таргете, в ходе работы используем методы борьбы с дисбалансом:
# 0   BeginDate           7043 non-null   datetime64[ns]
# 1   EndDate             1869 non-null   datetime64[ns]-
# - из обоих графиков распределения видно что количество отказов уменьшается с увеличением срока обслуживания, интересно провести большое исследование для выявления закономерностей причин отказа от обслуживания

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий тимлида🤔:</b> После сведения таблиц в общую появились пропуски, так как не все клиенты пользуются всеми услугами, поэтому мы не заполняем их средними или распространенными, а если там нет значения, то это NO
# </div>

# %% [markdown]
# ## Вопросы по плану и EDA
# - какие дополнительные признаки возможно создать?

# %% [markdown]
#
# <div class="alert alert-block alert-success">
# <b>Комментарий тимлида👍:</b> Основной признак тут это продолжительность сотрудничества в днях (ты его создал), номинально можно создать доп.признак - пользуется только телефонией, только интернетом, и телефонией, и интернетом.
#
# Нужно поправить:
#
# - импортирование (удали всё, что не относится к проекту)
# - момент в выводе про сведение таблиц.
#
# План принят, жду твой код =)
#
#
# </div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Работа с пропусками

# %%
#завершим работу с пропусками, проверим данные
full_df.isnull().sum()
# Out:
# Type                     0
# PaperlessBilling         0
# PaymentMethod            0
# TotalCharges             0
# SeniorCitizen            0
# Partner                  0
# Dependents               0
# InternetService       1526
# OnlineSecurity        1526
# OnlineBackup          1526
# DeviceProtection      1526
# TechSupport           1526
# StreamingTV           1526
# StreamingMovies       1526
# MultipleLines          682
# target                   0
# duration_service_d       0
# dtype: int64

# %%
#заменим пропуски на 'No' тк услуг не было оказано
for column in ['InternetService', 'OnlineSecurity', 'OnlineBackup', 
               'DeviceProtection','TechSupport', 'StreamingTV', 'StreamingMovies', 'MultipleLines']:
    full_df[column] = full_df[column].fillna('No')

# %%
#проверим данные после заполнения пропусков
full_df.isnull().sum()
# Out:
# Type                  0
# PaperlessBilling      0
# PaymentMethod         0
# TotalCharges          0
# SeniorCitizen         0
# Partner               0
# Dependents            0
# InternetService       0
# OnlineSecurity        0
# OnlineBackup          0
# DeviceProtection      0
# TechSupport           0
# StreamingTV           0
# StreamingMovies       0
# MultipleLines         0
# target                0
# duration_service_d    0
# dtype: int64

# %%
#проверим уникальные значения чтобы подтвердить корректность данных для дальнейшего обучения
for column in ['InternetService', 'OnlineSecurity', 'OnlineBackup', 
               'DeviceProtection','TechSupport', 'StreamingTV', 'StreamingMovies', 'MultipleLines']:
    print(full_df[column].unique())
# Out:
# ['DSL' 'Fiber optic' 'No']
# ['No' 'Yes']
# ['Yes' 'No']
# ['No' 'Yes']
# ['No' 'Yes']
# ['No' 'Yes']
# ['No' 'Yes']
# ['No' 'Yes']

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий тимлида👍:</b> Хорошо
# </div>

# %% [markdown]
# ### Применим технику прямого кодирования One-Hot Encoding (OHE)

# %%
#чтобы не попасть в dummy trap , применим аргумент drop_first функции pd.get_dummies(). 
df_ohe = pd.get_dummies(full_df, drop_first=True)
df_ohe
# Out:
#       TotalCharges  SeniorCitizen  target  duration_service_d  Type_One year  \
# 0            29.85              0       0                31.0              0
# 1          1889.50              0       0              1036.0              1
# 2           108.15              0       1                61.0              0
# 3          1840.75              0       0              1371.0              1
# 4           151.65              0       1                61.0              0
# ...            ...            ...     ...                 ...            ...
# 7038       1990.50              0       0               730.0              1
# 7039       7362.90              0       0              2191.0              1
# 7040        346.45              0       0               337.0              0
# 7041        306.60              1       1               123.0              0
# 7042       6844.50              0       0              2010.0              0
#
#       Type_Two year  PaperlessBilling_Yes  \
# ...

# %%
target = df_ohe['target'] # извлечем целевой признак

# %%
features = df_ohe.drop(['target'], axis=1) # извлечем признаки

# %%
#разделим данные на выборки 
features_train, features_test, target_train, target_test = train_test_split(
    features, target, test_size=0.25, random_state=290822) 

print('features', features.shape)
print('features_train', features_train.shape)
print('features_test', features_test.shape)
# Out:
# features (7043, 20)
# features_train (5282, 20)
# features_test (1761, 20)

# %% [markdown]
# ### Вывод
# - заменили пропуски категориальных признаков
# - применили технику прямого кодирования One-Hot Encoding (OHE), и чтобы не попасть в dummy trap , применили аргумент drop_first функции pd.get_dummies().
# - извлекли целевой признак, признаки, разделили данные на обучающую и тестовую выборки

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий тимлида👍:</b> Согласна, разделение корректно
# </div>

# %% [markdown]
# ## Обучение и CV. Выобор AUC-ROC лучшей модели

# %% [markdown]
# ### Проверка адекватности модели. Константная модель

# %%
#для подсчёта классов в целевом признаке применим метод value_counts(). Сделаем частоты относительными (от 0 до 1)
class_frequency = full_df['target'].value_counts(normalize=True)
print(class_frequency)
class_frequency.plot(kind='bar') #построим диаграмму
# Out:
# 0    0.73463
# 1    0.26537
# Name: target, dtype: float64
# <AxesSubplot:>

# %%
#Создадим константную модель: любому объекту она прогнозирует класс «0» и Сохраните её предсказания в target_pred_constant.
target_pred_const =  pd.Series(0, index=full_df['target'].index) 

#Accuracy
accuracy_const = accuracy_score(full_df['target'], target_pred_const)
print("accuracy_score: {0:.3f} ".format(accuracy_const))
#F1
f1_const = f1_score(full_df['target'], target_pred_const)
print("f1_score: {0:.3f} ".format(f1_const))
# Out:
# accuracy_score: 0.735
# f1_score: 0.000

# %% [markdown]
# ### LogisticRegression + class_weight='balanced'

# %%
#отключим предупреждением библиотеки sklearn при обучении логистической регрессии, 
#укажем аргумент solver='liblinear' (англ. solver «алгоритм решения»; library linear, «библиотека линейных алгоритмов»)
model = LogisticRegression(random_state=290822, solver='liblinear', class_weight='balanced')

scores = cross_val_score(model, features_train, target_train, scoring='roc_auc', cv=5, n_jobs = -1)
auc_roc_LR_bal = scores.mean()
print('Средняя оценка качества модели:', auc_roc_LR_bal)
# Out:
# Средняя оценка качества модели: 0.8467881536624189

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий тимлида❌:</b> Мы не тестируем все модели, лучшая модель выбирается на кросс-валидации, и только её мы тестируем
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий тимлида V.2👍:</b> Хорошо
# </div>

# %% [markdown]
# ### RandomForestClassifier + class_weight='balanced' + GridSearchCV

# %%
#%%time

#объявляем классификатор
model = RandomForestClassifier(random_state=290822, class_weight='balanced')

#создаем словарь, в который вписываем параметры, которые будем прогонять GridSearch’ем
parametrs = { 'n_estimators': range (10, 51, 10),
              'max_depth': range (1, 15, 2),
              'min_samples_leaf': range (1, 8),
              'min_samples_split': range (2, 10, 2),
            }

#запускаем обучение (n_jobs = -1, использовать все ЦП для обучения, по умолчанию 1 - использовать 1 ЦП)
grid = GridSearchCV(model, parametrs, cv=3, n_jobs = -1, scoring='roc_auc', verbose=3) # f1
grid.fit(features_train, target_train)

#Чтобы не переписывать параметры вручную и автоматически создать модель с наилучшими параметрами.
model_RandomForestClassifier_GridSearchCV = grid.best_estimator_

#выводим лучшие параметры
grid.best_params_
# Out:
# Fitting 3 folds for each of 980 candidates, totalling 2940 fits
# {'max_depth': 9,
#  'min_samples_leaf': 5,
#  'min_samples_split': 2,
#  'n_estimators': 50}

# %%
model = RandomForestClassifier(random_state=290822, n_estimators=50, min_samples_split=2, min_samples_leaf=5, 
                              max_depth=9, class_weight='balanced') 

scores = cross_val_score(model, features_train, target_train, scoring='roc_auc', cv=3, n_jobs = -1)
auc_roc_RFC_bal = scores.mean()
print('Средняя оценка качества модели:', auc_roc_RFC_bal)
# Out:
# Средняя оценка качества модели: 0.8577286197913091

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий тимлида❌:</b> Random state мы используем внутри модели, т.е. тут внутри RandomForestClassifier(), не нужно перебирать random state внутри параметров
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий тимлида V.2👍:</b> Хорошо
# </div>

# %% [markdown]
# ### CatBoostClassifier + GridSearchCV

# %%
#объявим классификатор
model = CatBoostClassifier(random_state=290822)

#создаем словарь, в который вписываем параметры, которые будем прогонять GridSearch’ем
parametrs = {'reg_lambda':[1,3,6],
             'learning_rate':[0.001, 0.01,0.1]                           
            }

#запускаем обучение (n_jobs = -1, использовать все ЦП для обучения, по умолчанию 1 - использовать 1 ЦП)
grid = GridSearchCV(model, parametrs, cv=3, n_jobs = -1, scoring='roc_auc', verbose=3)
grid.fit(features_train, target_train)

#выводим лучшие параметры
print(grid.best_params_)
print(grid.best_score_)

model = grid.best_estimator_
dump(model, 'CatBoostClassifier.joblib')
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# 0:	learn: 0.6231323	total: 139ms	remaining: 2m 19s
# 1:	learn: 0.5806220	total: 144ms	remaining: 1m 11s
# 2:	learn: 0.5442725	total: 148ms	remaining: 49.2s
# 3:	learn: 0.5142020	total: 152ms	remaining: 37.8s
# 4:	learn: 0.4941931	total: 156ms	remaining: 31s
# 5:	learn: 0.4745203	total: 160ms	remaining: 26.5s
# 6:	learn: 0.4600672	total: 164ms	remaining: 23.3s
# 7:	learn: 0.4497192	total: 169ms	remaining: 20.9s
# 8:	learn: 0.4396409	total: 173ms	remaining: 19s
# 9:	learn: 0.4311779	total: 177ms	remaining: 17.5s
# 10:	learn: 0.4254134	total: 181ms	remaining: 16.3s
# 11:	learn: 0.4188519	total: 185ms	remaining: 15.2s
# 12:	learn: 0.4110211	total: 189ms	remaining: 14.3s
# 13:	learn: 0.4067533	total: 193ms	remaining: 13.6s
# 14:	learn: 0.4032244	total: 197ms	remaining: 13s
# 15:	learn: 0.3993978	total: 201ms	remaining: 12.4s
# 16:	learn: 0.3962092	total: 205ms	remaining: 11.8s
# ...

# %%
model = joblib.load('CatBoostClassifier.joblib')

scores = cross_val_score(model, features_train, target_train, scoring='roc_auc', cv=3, n_jobs = -1)
auc_roc_CBC_grid = scores.mean()
print('Средняя оценка качества модели:', auc_roc_CBC_grid)
# Out:
# Средняя оценка качества модели: 0.9073408343089256

# %% [markdown]
# ### CatBoostClassifier + GridSearchCV + upsampling

# %% [markdown]
# #### Техника увеличения качества модели при дисбалансе классов: upsampling
# - Эта техника позволяет сделать объекты редкого класса не такими редкими и важные задачи повторяются по несколько раз, чтобы их легче запомнить модели.

# %%
#функция для upsampling
def upsample(features, target, repeat):
    features_zeros = features[target == 0]
    features_ones = features[target == 1]
    target_zeros = target[target == 0]
    target_ones = target[target == 1]

    features_upsampled = pd.concat([features_zeros] + [features_ones] * repeat)
    target_upsampled = pd.concat([target_zeros] + [target_ones] * repeat)
    
    features_upsampled, target_upsampled = shuffle(
        features_upsampled, target_upsampled, random_state=12345)
    
    return features_upsampled, target_upsampled

#сравняем количество 0 и 1, домножив 1 на 3
features_upsampled, target_upsampled = upsample(features_train, target_train, 3)

# %%
#объявим классификатор  
model = CatBoostClassifier(random_state=290822)

#создаем словарь, в который вписываем параметры, которые будем прогонять GridSearch’ем
parametrs = {'reg_lambda':[1,3,6],
             'learning_rate':[0.001, 0.01,0.1]                           
            }

#запускаем обучение (n_jobs = -1, использовать все ЦП для обучения, по умолчанию 1 - использовать 1 ЦП)
grid = GridSearchCV(model, parametrs, cv=3, n_jobs = -1, scoring='roc_auc', verbose=0)
grid.fit(features_upsampled, target_upsampled)

#выводим лучшие параметры
print(grid.best_params_)
print(grid.best_score_)

model = grid.best_estimator_
dump(model, 'CatBoostClassifier_upsampling.joblib')
# Out:
# 0:	learn: 0.6454610	total: 4.06ms	remaining: 4.06s
# 1:	learn: 0.6084650	total: 8.94ms	remaining: 4.46s
# 2:	learn: 0.5806804	total: 13.6ms	remaining: 4.51s
# 3:	learn: 0.5511090	total: 17.9ms	remaining: 4.46s
# 4:	learn: 0.5343681	total: 23.1ms	remaining: 4.59s
# 5:	learn: 0.5195704	total: 30.2ms	remaining: 5s
# 6:	learn: 0.5074883	total: 35.2ms	remaining: 4.99s
# 7:	learn: 0.4976360	total: 40.4ms	remaining: 5.01s
# 8:	learn: 0.4896611	total: 45.8ms	remaining: 5.05s
# 9:	learn: 0.4825341	total: 50.2ms	remaining: 4.97s
# 10:	learn: 0.4776792	total: 56ms	remaining: 5.03s
# 11:	learn: 0.4701030	total: 60.5ms	remaining: 4.98s
# 12:	learn: 0.4663863	total: 65ms	remaining: 4.93s
# 13:	learn: 0.4630889	total: 69ms	remaining: 4.86s
# 14:	learn: 0.4583532	total: 73.5ms	remaining: 4.82s
# 15:	learn: 0.4542603	total: 78.2ms	remaining: 4.81s
# 16:	learn: 0.4520788	total: 82.5ms	remaining: 4.77s
# 17:	learn: 0.4482092	total: 86.6ms	remaining: 4.72s
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий тимлида V.2❌:</b> Random state мы используем внутри модели, т.е. тут внутри RandomForestClassifier(), не нужно перебирать random state внутри параметров
# </div>

# %%
model = joblib.load('CatBoostClassifier_upsampling.joblib')

scores = cross_val_score(model, features_train, target_train, scoring='roc_auc', cv=3, n_jobs = -1)
auc_roc_CBC_grid_ups = scores.mean()
print('Средняя оценка качества модели:', auc_roc_CBC_grid_ups)
# Out:
# Средняя оценка качества модели: 0.9040210269498116

# %% [markdown]
# ### Вывод, результаты обучения

# %%
#результаты

rows = [
    ['-'], 
    ["{0:.4f} ".format(auc_roc_LR_bal)],     
    ["{0:.4f} ".format(auc_roc_RFC_bal)],
    ["{0:.4f} ".format(auc_roc_CBC_grid)],    
    ["{0:.4f} ".format(auc_roc_CBC_grid_ups)]
]


columns = ['AUC-ROC'] 

model = ['Константная модель (train)', 
         'LogisticRegression + class_weight=balanced (train)', 
         'RandomForestClassifier + class_weight=balanced + GridSearchCV (train)', 
         'CatBoostClassifier + GridSearchCV (train)', 
         'CatBoostClassifier + GridSearchCV + upsampling (train)']

results = pd.DataFrame(data=rows, index=model, columns=columns) # создаём таблицу и сохраняем её в переменную
display(results)
# Out:
#                                                     AUC-ROC
# Константная модель (train)                                -
# LogisticRegression + class_weight=balanced (train)  0.8468
# RandomForestClassifier + class_weight=balanced ...  0.8577
# CatBoostClassifier + GridSearchCV (train)           0.9073
# CatBoostClassifier + GridSearchCV + upsampling ...  0.9040

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий тимлида V.2👍:</b> Отлично, на кросс-валидации лучший вариант кэтбуст с подбором гиперпараметров
# </div>

# %% [markdown]
# ## Тестирование лучшей модели CatBoostClassifier + GridSearchCV

# %%
#Load best model from file 
model = joblib.load('CatBoostClassifier.joblib')

predicted_test = model.predict(features_test)
#Accuracy
accuracy_CBC_grid_test = accuracy_score(target_test, predicted_test)
print("accuracy_score: {0:.3f} ".format(accuracy_CBC_grid_test))
#F1
f1_CBC_grid_test = f1_score(target_test, predicted_test)
print("f1_score: {0:.3f} ".format(f1_CBC_grid_test))

#AUC-ROC
probabilities_test = model.predict_proba(features_test)
probabilities_one_test = probabilities_test[:, 1]
#рассчитаем AUC-ROC
auc_roc_CBC_grid_test = roc_auc_score(target_test, probabilities_one_test)
print("auc_roc: {0:.4f} ".format(auc_roc_CBC_grid_test))
# Out:
# accuracy_score: 0.875
# f1_score: 0.747
# auc_roc: 0.9205

# %% [markdown]
# ### Построим график важности признаков для итоговой модели

# %%
clf = joblib.load('CatBoostClassifier.joblib')
clf.fit(features, target)
# create a figure to plot a bar, where x axis is features, and Y indicating the importance of each feature
plt.figure(figsize=(20,10))
plt.bar(features.columns, clf.feature_importances_)
plt.xticks(rotation=90)

plt.grid(True)
plt.show()
# Out:
# 0:	learn: 0.6249357	total: 4.88ms	remaining: 4.88s
# 1:	learn: 0.5807649	total: 8.99ms	remaining: 4.49s
# 2:	learn: 0.5462944	total: 12.8ms	remaining: 4.25s
# 3:	learn: 0.5172581	total: 16.7ms	remaining: 4.16s
# 4:	learn: 0.4931494	total: 21.1ms	remaining: 4.21s
# 5:	learn: 0.4739675	total: 25.8ms	remaining: 4.28s
# 6:	learn: 0.4605441	total: 29.7ms	remaining: 4.21s
# 7:	learn: 0.4501697	total: 33.7ms	remaining: 4.18s
# 8:	learn: 0.4408102	total: 37.7ms	remaining: 4.16s
# 9:	learn: 0.4312886	total: 41.5ms	remaining: 4.11s
# 10:	learn: 0.4250819	total: 45.5ms	remaining: 4.09s
# 11:	learn: 0.4183037	total: 49.7ms	remaining: 4.09s
# 12:	learn: 0.4117310	total: 53.8ms	remaining: 4.08s
# 13:	learn: 0.4092013	total: 56.6ms	remaining: 3.98s
# 14:	learn: 0.4073748	total: 59.8ms	remaining: 3.93s
# 15:	learn: 0.4024397	total: 63.5ms	remaining: 3.91s
# 16:	learn: 0.3993487	total: 67.6ms	remaining: 3.91s
# 17:	learn: 0.3970018	total: 71.4ms	remaining: 3.9s
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Комментарий тимлида V.2🤔:</b> Перенеси, пожалуйста, импорт в первую ячейку и нампай у тебя уже загружен
# </div>

# %% [markdown]
# ### график: ROC-кривая

# %%
#Load best model from file 
model = joblib.load('CatBoostClassifier.joblib')

probabilities_test = model.predict_proba(features_test)
probabilities_one_test = probabilities_test[:, 1]

fpr, tpr, thresholds = roc_curve(target_test, probabilities_one_test)
plt.figure()

#постороим график: ROC-кривая случайной модели (выглядит как прямая)
plt.plot(fpr, tpr)
plt.plot([0, 1], [0, 1], linestyle='--')
#примените функции plt.xlim() и plt.ylim(), чтобы  установить границы осей от 0 до 1
plt.ylim([0.0, 1.0])
plt.xlim([0.0, 1.0])

#применим функции plt.xlabel() и plt.ylabel(), чтобы подписать оси "False Positive Rate" и "True Positive Rate"
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
#добавим к графику заголовок "ROC-кривая" функцией plt.title()
plt.title('ROC-кривая')
plt.show()

# %% [markdown]
# ### Вывод
# - обучили 3 разных модели
# - применили для меделей LogisticRegression и RandomForestClassifier - class_weight='balanced' для нивелирования дисбаланса данных
# - с той же целью для модели - CatBoostClassifier использовали upsampling
# - применили GridSearchCV для перебора гиперпараметров моделей
# - результаты сравнения метрик моделей свели в таблицу ниже

# %% [markdown]
# ## Общий вывод
# - в ходе работы преодолели минимально необходимый порог метрики AUC-ROC 0,75
# - лучшая модель согласно метрике AUC-ROC - CatBoostClassifier + GridSearchCV, значение метрики 0.9205
# - лучшая модель CatBoostClassifier + GridSearchCV согласно метрике Accuracy превосходит Константную модель на 0,14
# - для повышения метрик на будущее рекомендуется:
#     - использовать для обучения (при наличии) больше исходных данных (7тысяч записей - небольшая выборка)
#     - создать дополнительные признаки
#     - использовать бóльший диапазон и перечень гиперпараметров для перебора с помощью GridSearchCV

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий тимлида❌:</b> Спасибо тебе за проделанную работу, сейчас я не могу принять твой код, поэтому придётся ещё немного поработать:
#
# - мы выбираем лучшую модель на кросс-валидации, а потом тестируем только её, не нужно тестировать все модели;
# - не нужно перебирать random_state внутри гридсерч;
# - построй график важности признаков для итоговой модели.
#
# До встречи =)
# </div>

# %% [markdown]
# ## Эксперимент. Проверим метрики, обучив модель только на наиболее важных признаках по графику, поменяем столбцы и изучим метрики

# %%
list(df_ohe.columns)
# Out:
# ['TotalCharges',
#  'SeniorCitizen',
#  'target',
#  'duration_service_d',
#  'Type_One year',
#  'Type_Two year',
#  'PaperlessBilling_Yes',
#  'PaymentMethod_Credit card (automatic)',
#  'PaymentMethod_Electronic check',
#  'PaymentMethod_Mailed check',
#  'Partner_Yes',
#  'Dependents_Yes',
#  'InternetService_Fiber optic',
#  'InternetService_No',
#  'OnlineSecurity_Yes',
#  'OnlineBackup_Yes',
#  'DeviceProtection_Yes',
#  'TechSupport_Yes',
#  'StreamingTV_Yes',
#  'StreamingMovies_Yes',
#  'MultipleLines_Yes']

# %%
features_core = df_ohe.loc[: , ['duration_service_d', 'Type_Two year',  
                                'InternetService_Fiber optic', 'InternetService_No']]

# %%
#разделим данные на выборки 
features_train_core, features_test_core, target_train_core, target_test_core = train_test_split(
    features_core, target, test_size=0.25, random_state=290822) 

print('features', features_core.shape)
print('features_train', features_train_core.shape)
print('features_test', features_test_core.shape)
# Out:
# features (7043, 4)
# features_train (5282, 4)
# features_test (1761, 4)

# %%
#объявим классификатор
model = CatBoostClassifier(random_state=290822)

#создаем словарь, в который вписываем параметры, которые будем прогонять GridSearch’ем
parametrs = {'reg_lambda':[1,3,6],
             'learning_rate':[0.001, 0.01,0.1]                           
            }

#запускаем обучение (n_jobs = -1, использовать все ЦП для обучения, по умолчанию 1 - использовать 1 ЦП)
grid = GridSearchCV(model, parametrs, cv=3, n_jobs = -1, scoring='roc_auc', verbose=3)
grid.fit(features_train_core, target_train_core)

#выводим лучшие параметры
print(grid.best_params_)
print(grid.best_score_)

model = grid.best_estimator_
dump(model, 'CatBoostClassifier_core.joblib')
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# 0:	learn: 0.6272637	total: 4.02ms	remaining: 4.01s
# 1:	learn: 0.5743505	total: 8.89ms	remaining: 4.44s
# 2:	learn: 0.5379072	total: 13.3ms	remaining: 4.41s
# 3:	learn: 0.5115633	total: 17.7ms	remaining: 4.42s
# 4:	learn: 0.4901173	total: 21.7ms	remaining: 4.32s
# 5:	learn: 0.4725545	total: 25.4ms	remaining: 4.21s
# 6:	learn: 0.4571812	total: 29.8ms	remaining: 4.22s
# 7:	learn: 0.4459932	total: 34.1ms	remaining: 4.23s
# 8:	learn: 0.4374552	total: 37.5ms	remaining: 4.13s
# 9:	learn: 0.4266315	total: 40.5ms	remaining: 4.01s
# 10:	learn: 0.4210467	total: 45.1ms	remaining: 4.06s
# 11:	learn: 0.4169883	total: 49.6ms	remaining: 4.08s
# 12:	learn: 0.4139022	total: 52.6ms	remaining: 3.99s
# 13:	learn: 0.4121955	total: 55.2ms	remaining: 3.88s
# 14:	learn: 0.4087800	total: 59.3ms	remaining: 3.9s
# 15:	learn: 0.4070827	total: 63.6ms	remaining: 3.91s
# 16:	learn: 0.4043167	total: 66.8ms	remaining: 3.86s
# ...

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий тимлида V.2❌:</b> Random state мы используем внутри модели, т.е. тут внутри RandomForestClassifier(), не нужно перебирать random state внутри параметров
# </div>

# %%
#Load best model from file 
model = joblib.load('CatBoostClassifier_core.joblib')

predicted_test_core = model.predict(features_test_core)
#Accuracy
accuracy_CBC_grid_core = accuracy_score(target_test_core, predicted_test_core)
print("accuracy_score: {0:.3f} ".format(accuracy_CBC_grid_core))
#F1
f1_CBC_grid_core = f1_score(target_test_core, predicted_test_core)
print("f1_score: {0:.3f} ".format(f1_CBC_grid_core))

#AUC-ROC
probabilities_test_core = model.predict_proba(features_test_core)
probabilities_one_test_core = probabilities_test_core[:, 1]
#рассчитаем AUC-ROC
auc_roc_CBC_grid_core = roc_auc_score(target_test_core, probabilities_one_test_core)
print("auc_roc: {0:.4f} ".format(auc_roc_CBC_grid_core))
# Out:
# accuracy_score: 0.895
# f1_score: 0.783
# auc_roc: 0.9447

# %% [markdown]
# # Вопросы
# 1) Виктория привет! Подскажи пожалуйста несколько моментов
# - почему эти столбцы
#     - features_core = df_ohe.loc[: , ['duration_service_d', 'Type_Two year', 'InternetService_Fiber optic', 'InternetService_No']]
# - дают метрику auc_roc больше
#     - accuracy_score: 0.895 f1_score: 0.783 auc_roc: 0.9447
# - чем эти столбцы
#     - features_core = df_ohe.loc[: , ['duration_service_d', 'Type_One year', 'Type_Two year','InternetService_Fiber optic']]
#     - accuracy_score: 0.896  f1_score: 0.785 auc_roc: 0.9393
# - Это же не логично из графиков важности?
#
# 2) сколько auc_roc в авторском решении?
# пришли пожалуйста авторски код чтобы мог сравнить и понять что могу улушить
#
# 3) порекомендуй пожалуйста другой график важности признаков для итоговой модели, если есть лучше/объективнее
#
# 4) как интерпретировать менеджеру организации что у меня аукрок 0,94, как это превести на простой язык, в чем суть метрики на примере данной задачи простыми словами?
#
# 5) как использовать параметр class_weight='balanced' для модели CatBoostClassifier чтобы не делать upsampling?
#
# 6) как добавить перебор интересующих нас столбцов с признаками например гридсерчем (GridSearchCV) ?

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Комментарий тимлида V.2👍:</b>
#
# 1. Потому что график важности признаков для модели меняется в зависимости от того какие признаки ты используешь, а так же меняется метрика. Бывает, что признак сам по себе не особо значим, но он является вот тем последним недостающим кусочком пазла.
#
# 2. Я не имею права показывать авторский код и присылать его студентам, он только для персонала. Другие варианты решения ты сможешь увидеть на финальном вебинаре. Если кто-то из ревьюеров когда либо показывал тебе авторское решение, то прошу указать проект, дабы наказать виновного😅
#
# 3. Тут все достаточно стандартно и нет никакой магии:
#
# - https://www.rasgoml.com/feature-engineering-tutorials/how-to-generate-feature-importance-plots-from-scikit-learn
# - https://betterdatascience.com/feature-importance-python/
#
#
# 4. Я слабо себе представляю ситуацию, что ты интерпретируешь менеджеру организации что у тебя метрика такая-то, скорее всего ты просто скажешь какие метрики ты использовал и что добился приемлемого результата, но наиболее понятное объяснение вот в этой статье: https://analyticsindiamag.com/understanding-the-auc-roc-curve-in-machine-learning-classification/
#
# 5. через auto_class_weights или задание веса класса 1 в параметре scale_pos_weight
#
# 6. Не очень поняла твой вопрос, ты имеешь ввиду чтобы модель перебирала разные независимые признаки? Такого нет и это неэффективно, обычно ты строишь модель, смотришь на график важности и убираешь или добавляешь признаки сам
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий тимлида V.2❌:</b> Не перебирай random_state в части эксперимент и я приму твой код =)
# </div>

# %% [markdown]
# # Вопросы
# Спасибо за инфо! Исправил
#
#
# 2. Авторский код упоминался в одной из конференций, мне ни разу не присылали его(
# Подскажи основные ОТЛИЧИЯ у меня с авторским код пожалуйста, ОЧЕНЬ ИНТЕРЕСНО ПОЛУЧИТЬ МАКСИМАЛЬНУЮ МЕТРИКУ 🙂😺

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Комментарий тимлида V.3❌:</b> Ты не убрал перебор random state из ячейки 43, уберёшь и расскажу😅
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий студента👍:</b> Виктория привет! определенно убирал везде, пару месяцев назад было такое что файл отправлялся без изменений. Сейчас скачал, изменил локально, дваждый сохранил и сделал скрин как подтверждение что изменил, прикладываю ниже.
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#
# <div class="alert alert-block alert-success">
# <b>Комментарий тимлида V.4👍:</b> Теперь поправилось =) На тестовой выборке у тебя 0.94, что соответствует 6 sp. Жду твой отчёт, я в свою очередь подготовлю тебе перечень что ещё можно было использовать в работе и скину ссылки на решения =)

# %% [markdown]
# ## Отчет
#         a) Какие пункты плана были выполнены, а какие — нет (поясните почему)?
#         b) Какие трудности возникли и как вы их преодолели?
#         c) Какие ключевые шаги в решении задачи выделили?
#         d) Какая ваша итоговая модель и какое у неё качество?

# %% [markdown]
#     a.1) Были выполнены пункты плана:
#    - 1 One-Hot Encoding
#    - 2 Разделение исходных данных на обучающую и тестовую выборки
#    - 4 Исследование баланса классов
#    - 5 Принято решение оставить 3 модели по градациям: наиболее простую и быструю, более сложную и модель градиентного бустинга. Выбран RandomForestClassifier вместо DecisionTreeClassifier как более точный и мощный иснтрумент, из пары моделеей градиентного бустинга: LGBMClassifier и CatBoostClassifier - выбран второй как более точнный инструмент (из опыта, в плане качества метрик) при примерно одинаковом времени обучения.
#    - 6 Улучшение качества модели, учитывая дисбаланс классов. Обучение разных моделей и поиск лучшей.
#       - Техника увеличения качества модели при дисбалансе классов: Взвешивание классов (class_weight='balanced')
#       - Техника увеличения качества модели при дисбалансе классов: upsampling
#
#     a.2) Не выполнены:
#    - 3 Применение масштабирования признаков методом стандартизации данных. Принято решение использовать данный этап как дополнение если получим недостаточно высокие метрики на тесте, и вместо него сосредоточиться на процессе подбора гиперпараметров.
#        -7 При необходимости (если низкие метрики) создать дополнительные признаки или запустим на длительный период (несколько часов) для подбора лучших гиперпараметров. Данный пункт не понадобился тк мы преодолели необходимый порог метрики,однако вместо него с целью улучшения результатов поэксперементировали с выбором признаков для обучения, что дало +0,02 к ключевой метрике.
#
#     b) Возникла трудность с созданием корректных значений нового признака duration_service_d (сроком обслуживания), решить вопрос помогли лекции Яндекс из нашего курса, поиск решения отдельных шагов в интернете и в первую очередь четко составленный алгоритм действий.
#
#     с) Субъективно и обобщенно возможно выделить следующие ключевые шаги: составление плана, анализ и предобработка датасета в т.ч создание целевого признака, выбор и обучение моделей, использование инструментов и методов повышения метрик.
#
#     d) Итоговая модель:
#     - модель -CatBoostClassifier.
#     - подбор гиперпараметров - с GridSearchCV (cv=3, n_jobs = -1, scoring='roc_auc', verbose=3), итоговые г/п: 'learning_rate': 0.1, 'random_state': 290822, 'reg_lambda': 6, random_state - при разделении выборки и в качестве параметра модели использован =290822.
#     - признаки для обучения итоговой модели выбранны с помощью графика важности признаков и ручного перебора: 'duration_service_d' (признак получен разностью даты (Информация о договорах актуальна на 1 февраля 2020) и даты начала даговора там где нет даты окончания договора, и разностью даты начала и окончания договора), 'Type_Two year', 'InternetService_Fiber optic', 'InternetService_No'. Признаки предобработаны с помощью приведения к соответствующему типу данных для произведения дальнейших вычислений и заполнение пропущенных значений по смыслу задачи (например там где были пропуски услуги InternetService после объединения датасетов - заполнено 'No').
#     - размер тестовой выборки 25%- test_size=0.25
#     Метрика качества итоговой модели: accuracy_score: auc_roc: 0.9447, доп метрики: 0.895, f1_score: 0.783.
#
#     Субъективно, на основе скромного опыта, возможно сказать что получена достаточно высокая метрика для решения задачи и внедрения для принятия бизнес решений. Дополнительно возможно группировать пользователей по различным признакам, исследовать гипотезы на предмет отказа от обслуживания при сочетании определенных признаков а также предложить маркетинговые ходы (скидки, триал версии услуг) для групп с наибольшим риском ухода.
#
#     Для улучшения качества модели возможно создать новые признаки, исследовать новые инструменты изучения важности признаков и их влияния на качество модели, разработать собственную функцию перебора и включения признаков для обучения модели чтобы все "кусочки пазла" стали на свое место и не было дубликатов или кусочков пазла мешающих обучению модели.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий тимлида</b>
#
# Роман, поздравляю тебя с завершением проекта🥳
#
# Перечислю моменты, которые можно улучшить:
#
# 1) Кодировать данные нужно после разделения на выборки, а не до;
#
# 2) Get_dummies вообще используется по большей части для анализа, для кодирования лучше использовать one hot encoder https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OneHotEncoder.html.
#
# Если руководствоваться сейчас твоим кодом, то непонятно как делать в ситуации если заказчик даст тебе новую тестовую выборку
#
#
# 3) Использовать пайплайны
#
# 4) Крайне рекомендуется стандартизировать числовые признаки;
#
# 5) Вот такой метод не нужно в реальной практике использовать вообще никогда:
#
# def upsample(features, target, repeat):
#
#     features_zeros = features[target == 0]
#
#     features_ones = features[target == 1]
#
#     target_zeros = target[target == 0]
#
#     target_ones = target[target == 1]
#
# Так как по факту ты просто создаёшь дубликаты, что вызывает утечку данных
#
# Для upsampling'а лучше использовать SMOTE и гибридные техники https://www.analyticsvidhya.com/blog/2020/10/overcoming-class-imbalance-using-smote-techniques/ (нужен VPN)
#
#
# Ссылки на работы-примеры я скину после вебинара в слак =)
#
#
# Я предлагаю тебе подумать что тебе было бы интересно почитать/изучить после окончания курса, ты можешь написать мне в личные сообщения до понедельника и я сделаю подборку.
#
# Eщё раз поздравляю и до встречи на финальном вебинаре!
#
# </div>
